# %%
import os
import openai

# %%
api_key = os.getenv("OPENAI_API_KEY")

if api_key is None:
    raise ValueError("Set OPENAI_API_KEY in your environment variables")
else:
    print(f"OPENAI_API_KEY: {api_key}")
# Out:
# OPENAI_API_KEY: sk-4xppptv_yIQIrxN1FKt7lgpS3ZhXmgLm7gl1aGWJUFT3BlbkFJsJhu2WrYODm1CK_W8A2oKmVOdwsYqQU8xE6KitNdYA

# %%
openai.api_key = api_key

# %%
# Example prompt
response = openai.ChatCompletion.create(
    model="GPT-4.1",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Explain the difference between supervised and unsupervised learning."}
    ],
    temperature=0.7
)

# Print the response
print(response['choices'][0]['message']['content'])
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Example prompt
# ----> 2 response = openai.ChatCompletion.create(
#       3     model="GPT-4.1",
#       4     messages=[
#       5         {"role": "system", "content": "You are a helpful assistant."},
#       6         {"role": "user", "content": "Explain the difference between supervised and unsupervised learning."}
#       7     ],
#       8     temperature=0.7
#       9 )
#      11 # Print the response
#      12 print(response['choices'][0]['message']['content'])
#
# File ~/code/github/openai_api_testing/venv/lib/python3.12/site-packages/openai/lib/_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
